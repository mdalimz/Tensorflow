# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from zipfile import ZipFile
from urllib.request import urlretrieve

from IPython.display import Image

# %% [markdown]
# In this notebook the following image transformations is goin to cover,
# * Accessing and manipulating images pixels
# * Image resizing
# * Cropping
# * Flipping

# %% [markdown]
# - Accessing and manipulating images pixels

# %%
Image
# Out:
# IPython.core.display.Image

# %%
img = cv2.imread("D:\opencvimage\image.jpg", 0)   ## Reading image as gray scale mode

# Set color map to gray scale for proper rendering.
plt.imshow(img, cmap="gray")
print(img)
# Out:
# [[125 125 125 ... 129 129 129]
#  [125 125 125 ... 129 129 129]
#  [125 125 125 ... 130 130 130]
#  ...
#  [109 109 109 ... 110 111 111]
#  [109 109 109 ... 110 111 111]
#  [109 109 109 ... 110 110 110]]

# %%
# print the first pixel of the first black box
print(img[0, 100])
# print the first white pixel to the right of the first black box
print(img[0, 6])
# Out:
# 137
# 125
